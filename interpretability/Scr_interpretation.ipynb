# %%
import numpy as np
import sys
sys.path.append('../')
from utils import build_dataset
import torch
from torch.optim import Adam
from torch.utils.data import DataLoader
from utils.GNN import collate_molgraphs, EarlyStopping, run_an_eval_epoch_heterogeneous_return_weight,\
 set_random_seed, MGA, run_an_eval_epoch_heterogeneous_generate_weight
from utils.GNN import pos_weight
import os
import time
import pandas as pd

start = time.time()
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# fix parameters of model
args = {}
args['device'] = "cuda" if torch.cuda.is_available() else "cpu"
args['atom_data_field'] = 'atom'
args['bond_data_field'] = 'etype'
args['classification_metric_name'] = 'roc_auc'
args['regression_metric_name'] = 'r2'
# model parameter
args['num_epochs'] = 500
args['patience'] = 50
args['batch_size'] = 256
args['mode'] = 'higher'
args['in_feats'] = 40
args['rgcn_hidden_feats'] = [256, 128]
args['classifier_hidden_feats'] = 128
args['rgcn_drop_out'] = 0.3
args['drop_out'] = 0.3
args['lr'] = 3
args['weight_decay'] = 5
args['loop'] = True

# task name (model name)
args['task_name'] = 'MTL'  # change
args['data_name'] = '/'  # change
args['times'] = 1

# selected task, generate select task index, task class, and classification_num
args['select_task_list'] = ['/'] # change
args['select_task_index'] = []
args['classification_num'] = 0
args['regression_num'] = 0
args['all_task_list'] =['/']# change
# generate select task index
for index, task in enumerate(args['all_task_list']):
    if task in args['select_task_list']:
        args['select_task_index'].append(index)
# generate classification_num
for task in args['select_task_list']:
    if task in ['/']:
        args['classification_num'] = args['classification_num'] + 1
    if task in ['']:
        args['regression_num'] = args['regression_num'] + 1
# generate classification_num
if args['classification_num'] != 0 and args['regression_num'] != 0:
    args['task_class'] = 'classification_regression'
if args['classification_num'] != 0 and args['regression_num'] == 0:
    args['task_class'] = 'classification'
if args['classification_num'] == 0 and args['regression_num'] != 0:
    args['task_class'] = 'regression'

args['bin_path'] = '../data/' + args['data_name'] + '.bin'
args['group_path'] = '../data/' + args['data_name'] + '_group.csv'

result_pd = pd.DataFrame(columns=args['select_task_list'] + ['group'] + args['select_task_list'] + ['group']
                                 + args['select_task_list'] + ['group'])
all_times_train_result = []
all_times_val_result = []
all_times_test_result = []
for time_id in range(args['times']):
    set_random_seed(2020 + time_id)
    one_time_train_result = []
    one_time_val_result = []
    one_time_test_result = []
    print('***************************************************************************************************')
    print('{}, {}/{} time'.format(args['task_name'], time_id + 1, args['times']))
    print('***************************************************************************************************')
    train_set, val_set, test_set, task_number = build_dataset.load_graph_from_csv_bin_for_splited(
        bin_path=args['bin_path'],
        group_path=args['group_path'],
        select_task_index=args['select_task_index']
    )
    print("Molecule graph generation is complete !")
    train_loader = DataLoader(dataset=train_set,
                              batch_size=args['batch_size'],
                              shuffle=True,
                              collate_fn=collate_molgraphs)

    val_loader = DataLoader(dataset=val_set,
                            batch_size=args['batch_size'],
                            shuffle=True,
                            collate_fn=collate_molgraphs)

    test_loader = DataLoader(dataset=test_set,
                             batch_size=args['batch_size'],
                             collate_fn=collate_molgraphs)
    pos_weight_np = pos_weight(train_set, classification_num=args['classification_num'])
    loss_criterion_c = torch.nn.BCEWithLogitsLoss(reduction='none', pos_weight=pos_weight_np.to(args['device']))
    loss_criterion_r = torch.nn.MSELoss(reduction='none')
    model = MGA(in_feats=args['in_feats'], rgcn_hidden_feats=args['rgcn_hidden_feats'],
                n_tasks=/, rgcn_drop_out=args['rgcn_drop_out'],
                classifier_hidden_feats=args['classifier_hidden_feats'], dropout=args['drop_out'],
                loop=args['loop'], return_weight=True)
    optimizer = Adam(model.parameters(), lr=10 ** -args['lr'], weight_decay=10 ** -args['weight_decay'])
    stopper = EarlyStopping(patience=args['patience'], 
                            filename='/.pth',
                            task_name=args['task_name'], 
                            mode=args['mode'])
    model.to(args['device'])
    stopper.load_checkpoint(model)
    # selected test molecules
    selected_data = pd.read_excel('/.xlsx')
    selected_mol_list = selected_data['smiles'].tolist()
    # visual test set
    run_an_eval_epoch_heterogeneous_return_weight(args, model, test_loader, vis_list=selected_mol_list)
    # run_an_eval_epoch_heterogeneous_generate_weight(args, model, test_loader)
# Out:
# ***************************************************************************************************
# MTL, 1/1 time
# ***************************************************************************************************
# 3492 436 437 1
# Molecule graph generation is complete !
# E:\manuscript\水生毒性的集成预测\筛查模型\code\interpretation\..\utils\GNN.py:480: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:264.)
#   labels = torch.tensor(labels)
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9277, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# C=CC(C)(O)CCC=C(C)C
# [10:11:49] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.6426, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# ClCC(Cl)Cl
# [10:11:49] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9389, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCOC(=O)C1c2cc3c(cc2CC(C)C1C(=O)OCCC)OCO3
# [10:11:49] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9890, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# COP(=S)(OC)SCn1nnc2ccccc2c1=O
# [10:11:49] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9199, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=c1n(Cl)c(=O)n(Cl)c(=O)n1Cl
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.8467, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Nc1ccccc1[N+](=O)[O-]
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9653, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=Cc1ccccc1Cl
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9376, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Oc1ccc(-c2ccccc2)c(Cl)c1
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.4587, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=C(O)CCCOc1ccc(Cl)cc1Cl
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9667, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# c1ccc2sc(SNC3CCCCC3)nc2c1
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9792, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Cc1ccc(C)c(C)c1
# [10:11:50] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9445, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Clc1cc(Cl)c(Cl)cc1Cl
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.8953, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9559, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=[N+]([O-])c1ccc(Cl)c(Cl)c1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9460, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=[N+]([O-])c1ccc([N+](=O)[O-])cc1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9625, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CNc1ccccc1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9749, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CC(C)OC(=O)Nc1cccc(Cl)c1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9562, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCc1ccc(N)cc1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9153, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Cc1ccc(O)c(C)c1
# [10:11:51] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9758, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Clc1ccc(Cl)cc1
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.7615, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# C=C(C)C(=O)OCC1CO1
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.4896, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# C1CCCCC1
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9154, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCSCCC
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.5037, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCCCCCN
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.5536, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCCCCCCCO
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.8045, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# O=Cc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1[N+](=O)[O-]
# [10:11:52] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9833, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# ClCc1ccccc1Cl
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9455, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Cc1cc([N+](=O)[O-])ccc1[N+](=O)[O-]
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.6833, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCC(CC)C(=O)OOC(C)(C)C
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.7853, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CC(=O)Oc1c([N+](=O)[O-])cc([N+](=O)[O-])cc1C(C)(C)C
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.7405, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# N#Cc1sc2c(=O)c3ccccc3c(=O)c=2sc1C#N
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9751, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# COP1(=S)OCc2ccccc2O1
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9702, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# N#CC(Br)(Br)C(N)=O
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9164, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Oc1cc(Cl)cc(Cl)c1O
# [10:11:53] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9780, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCc1cccc(CC)c1N(COC)C(=O)CCl
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9671, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# C(=CCOCc1ccccc1)COCc1ccccc1
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9236, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Nc1ccc(N=Nc2ccccc2)c(N)c1
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.6788, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# NCCc1ccccc1
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.7877, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Cc1cc(C(C#N)c2ccc(Cl)cc2)c(Cl)cc1NC(=O)c1cc(I)cc(I)c1O
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.6596, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# COc1cc(Nc2c(C#N)cnc3cc(OCCCN4CCN(C)CC4)c(OC)cc23)c(Cl)cc1Cl
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.6942, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CS(=O)CCCCN=C=S
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9763, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCC(=O)OC1C=CC2C3CCC(C3)C12
# [10:11:54] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9864, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# C1CN(SSN2CCOCC2)CCO1
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9370, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CC(C)c1ccc2ccccc2c1C(C)C
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9377, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CC(C)(C)S
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.8734, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# COC(=O)CCc1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9772, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCc1c(C)nc(NCC)nc1OS(=O)(=O)N(C)C
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9914, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCC(=O)N(CSP(=S)(OC)OC)c1ccccc1Cl
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9731, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CC(C)(NC(=O)NCc1ccccc1Cl)c1ccccc1
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.5837, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# CCCCCCC1CO1
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.8557, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# COc1c(O)c(Br)cc(C=O)c1[N+](=O)[O-]
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.9478, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# Nc1ccc(CCNCC(O)c2ccccc2)cc1
# [10:11:55] The new font size 1 is below the current minimum (6).
# Tasks: 0 FishAT **********************
# Predict values: tensor(0.7059, device='cuda:0')
# True values: tensor(1., device='cuda:0')
# N#CC1SC2=C(SC1C#N)C(=O)c1ccccc1C2=O
# [10:11:55] The new font size 1 is below the current minimum (6).
